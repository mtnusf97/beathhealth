# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, normalize
import scipy.cluster.hierarchy as shc
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from tqdm import tqdm
import torch
from torch import nn
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorboardX import SummaryWriter
import os
import time
from torcheval.metrics import R2Score
from sklearn.metrics import r2_score

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

# %% [markdown]
# # pipeline

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        if not torch.is_tensor(X) or not torch.is_tensor(y):
            X = torch.from_numpy(X)
            y = torch.from_numpy(y)
            
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]


class MLP(nn.Module):
    '''
        Multilayer Perceptron for regression.
    '''
    def __init__(self, n_in, n_out):
        super().__init__()
#         self.layers = nn.Sequential(
#             nn.Linear(n_in, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, n_out)
#         )
        
#         self.layers = nn.Sequential(
#             nn.Linear(n_in, 32),
#             nn.ReLU(),
#             nn.Linear(32, 64),
#             nn.ReLU(),
#             nn.Linear(64, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 16),
#             nn.ReLU(),
#             nn.Linear(16, n_out)
#         )

        self.layers = nn.Sequential(
            nn.Linear(n_in, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, n_out)
        )

#         self.layers = nn.Sequential(
#             nn.Linear(n_in, 32),
#             nn.ReLU(),
#             nn.Linear(32, 32),
#             nn.ReLU(),
#             nn.Linear(32, 32),
#             nn.ReLU(),
#             nn.Linear(32, n_out)
#         )


    def forward(self, x):
        '''
          Forward pass
        '''
        return self.layers(x)

# %%
def run_deep(X, y, idx, test_size, 
             train_batch_size, val_batch_size,
             learning_rate,
             tensorboard_path,
             print_iteration=1,
             n_epochs=100,
             tensorboard=True, 
             do_print=True):

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size)

    # Prepare dataset
    train_dataset = Dataset(X_train, y_train)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)

    val_dataset = Dataset(X_val, y_val)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=val_batch_size, shuffle=True)

    # Initialize the MLP
    mlp = MLP(n_in=X_train.shape[1], n_out=1)

    # Define the loss function and optimizer
    loss_function = nn.MSELoss(reduction='sum')
    optimizer = torch.optim.Adam(mlp.parameters(), lr=learning_rate)    
    
    if tensorboard:
        writer = SummaryWriter(tensorboard_path)
    
    # Run the training loop
    total_iteration = 0
    best_val_results = dict(loss = np.inf, corr = -np.inf, r2 = -np.inf)
    for epoch in range(n_epochs): 
        outputs_train_arr = np.array([])
        targets_train_arr = np.array([])

        current_loss = 0.0
        n_train_data = 0
        for inputs, targets in train_loader:
            total_iteration += 1
            inputs, targets = inputs.float(), targets.float()
            targets = targets.reshape((targets.shape[0], 1))
            n_train_data += inputs.shape[0]
            
            optimizer.zero_grad()
            
            outputs = mlp(inputs)
            loss = loss_function(outputs, targets)
            loss.backward()
            optimizer.step()
            current_loss += loss.item()
            
            outputs_detach = torch.detach(outputs)
            targets_detach = torch.detach(targets)
            outputs_train_arr = np.append(outputs_train_arr, torch.Tensor.numpy(outputs_detach).reshape(1,-1)[0])
            targets_train_arr = np.append(targets_train_arr, torch.Tensor.numpy(targets_detach).reshape(1,-1)[0])
                       
            if total_iteration % print_iteration == 0:
                loss_val = 0
                n_val_data = 0
                outputs_val_arr = np.array([])
                targets_val_arr = np.array([])

                for inputs_val, targets_val in val_loader:
                    inputs_val, targets_val = inputs_val.float(), targets_val.float()
                    targets_val = targets_val.reshape((targets_val.shape[0], 1))
                    n_val_data += inputs_val.shape[0]
                    outputs_val = mlp(inputs_val)
                    loss_val += loss_function(outputs_val, targets_val).item()
                    outputs_val_detach = torch.detach(outputs_val)
                    targets_val_detach = torch.detach(targets_val)
                    outputs_val_arr = np.append(outputs_val_arr, torch.Tensor.numpy(outputs_val_detach).reshape(1,-1)[0])
                    targets_val_arr = np.append(targets_val_arr, torch.Tensor.numpy(targets_val_detach).reshape(1,-1)[0])
                    
                corrcoef = np.corrcoef(targets_val_arr, outputs_val_arr)[0, 1]
                r_squared = r2_score(targets_val_arr, outputs_val_arr)
                train_loss = current_loss / n_train_data
                val_loss = loss_val / n_val_data
                
                if tensorboard:
                    writer.add_scalars(f'{str(idx)}_loss', {
                        'train': train_loss,
                        'validation': val_loss,
                    }, total_iteration)
                    writer.add_scalars(f'{str(idx)}_corr-R', {
                        'corr': corrcoef,
                        'r': r_squared,
                    }, total_iteration)
                
                if val_loss < best_val_results['loss']:
                    best_val_results['loss']
                best_val_results['loss'] = val_loss if val_loss < best_val_results['loss'] else best_val_results['loss']
                best_val_results['corr'] = corrcoef if corrcoef > best_val_results['corr'] else best_val_results['corr']
                best_val_results['r2'] = r_squared if r_squared > best_val_results['r2'] else best_val_results['r2']
                
                current_loss = 0.0
                n_train_data = 0
        
        corrcoef = np.corrcoef(targets_train_arr, outputs_train_arr)[0, 1]
        r_squared = r2_score(targets_train_arr, outputs_train_arr)
        
    print_str = (f"best of {str(idx).rjust(3)} => loss: {str(round(best_val_results['loss'], 2)).rjust(11)}, " + 
                 f"corr: {str(round(best_val_results['corr'], 2)).rjust(5)}, " + 
                 f"r2: {str(round(best_val_results['r2'], 2)).rjust(5)}")
    if do_print:
        print(print_str)
    
    if tensorboard:
        writer.add_text(str(idx), print_str)
        del writer
        
    return print_str, best_val_results

# %% [markdown]
# # run pipeline

# %%
# data

df_to_run = pd.read_csv('data/deep_test_retest_imputed.csv')
# df_to_run = pd.read_csv('data/deep_test_retest_imputed_measures_standardized.csv')
data_arr = df_to_run.iloc[:,2:].to_numpy()
X = data_arr[:, :12]
y_total = data_arr[:, 12:]

# %%
all_str = str()
for idx in range(56):
    y = y_total[:, idx]

    tensorboard_path = os.path.join('tensorboard5/', str(idx) + '_' + str(int(round(time.time() % 1, 5) * 1e5)))
    print_str, _ = run_deep(X, y, idx, 0.2, 
                         train_batch_size=10, val_batch_size=5, 
                         learning_rate=1e-3, 
                         tensorboard_path=tensorboard_path, 
                         print_iteration=1, 
                         n_epochs=100,
                         tensorboard=False)
    all_str += print_str + '\n'

f = open("1e-3_fancynet3.txt", "w")
f.write(all_str)
f.close()
# Out:
# best of   0 => loss:        0.61, corr:  0.45, r2:  0.17
# best of   1 => loss:        0.45, corr:  0.61, r2:  0.36
# best of   2 => loss:        0.51, corr:  0.18, r2: -0.16
# best of   3 => loss:        0.42, corr:   0.5, r2:  0.24
# best of   4 => loss:      204.36, corr:   0.3, r2:  0.03
# best of   5 => loss:       243.3, corr:  0.34, r2:  0.09
# best of   6 => loss:      252.73, corr:  0.29, r2: -0.28
# best of   7 => loss:      130.24, corr:  0.49, r2:  0.22
# best of   8 => loss:       99.66, corr:  0.43, r2:  0.15
# best of   9 => loss:      117.57, corr:  0.68, r2:  0.38
# best of  10 => loss:       23.17, corr:  0.34, r2:   0.1
# best of  11 => loss:       31.98, corr:  0.51, r2:  0.24
# best of  12 => loss:      178.75, corr:  0.15, r2: -0.25
# best of  13 => loss:        9.56, corr:  0.59, r2:  0.31
# best of  14 => loss:       43.94, corr:  0.28, r2: -0.04
# best of  15 => loss:         0.0, corr:  0.21, r2: -2.89
# best of  16 => loss:         0.0, corr:  0.49, r2: -1.49
# best of  17 => loss:         0.0, corr:  0.54, r2: -0.53
# best of  18 => loss:         0.0, corr:  0.47, r2: -4.68
# best of  19 => loss:     9622.44, corr:  0.66, r2:  0.42
# best of  20 => loss:     8418.38, corr:  0.52, r2:  0.24
# best of  21 => loss:    10215.22, corr:  0.43, r2:  0.16
# best of  22 => loss:   158737.07, corr:  0.17, r2:   0.0
# best of  23 => loss:         0.0, corr:  0.27, r2: -3.87
# best of  24 => loss:       35.91, corr:  0.32, r2:  0.09
# best of  25 => loss:      763.56, corr:  0.63, r2:  0.23
# best of  26 => loss:        0.41, corr:  0.68, r2:   0.3
# best of  27 => loss:         0.0, corr:  0.25, r2: -1.16
# best of  28 => loss:       43.18, corr:  0.28, r2:  -0.0
# best of  29 => loss:       215.3, corr:  0.24, r2:  0.03
# best of  30 => loss:        0.28, corr:  0.61, r2:  0.36
# best of  31 => loss:         0.0, corr:  0.45, r2: -0.82
# best of  32 => loss:       15.15, corr:  0.05, r2: -0.08
# best of  33 => loss:      384.34, corr:   0.7, r2:  0.27
# best of  34 => loss:        0.32, corr:  0.79, r2:  0.59
# best of  35 => loss:         0.0, corr:  0.17, r2: -6.12
# best of  36 => loss:       22.61, corr:  0.67, r2:  0.27
# best of  37 => loss:      414.76, corr:  0.48, r2:  0.15
# best of  38 => loss:        1.65, corr:   0.3, r2:  0.01
# best of  39 => loss:         0.0, corr:  0.27, r2: -0.93
# best of  40 => loss:       24.17, corr:  0.32, r2:  0.04
# best of  41 => loss:      936.47, corr:   0.1, r2:  0.01
# best of  42 => loss:        1.93, corr:  0.58, r2:  0.28
# best of  43 => loss:        0.23, corr: -0.02, r2: -0.22
# best of  44 => loss:        0.08, corr:  0.59, r2:  0.21
# best of  45 => loss:         0.0, corr:  0.25, r2: -1.59
# best of  46 => loss:        0.58, corr:  0.24, r2:  0.02
# best of  47 => loss:         0.2, corr:  0.43, r2:  0.18
# best of  48 => loss:        0.29, corr:  0.61, r2:  0.32
# best of  49 => loss:        0.09, corr:  0.28, r2: -0.18
# best of  50 => loss:         0.0, corr:  0.44, r2:  -0.9
# best of  51 => loss:         0.0, corr:   0.3, r2: -0.16
# best of  52 => loss:         0.0, corr:   0.3, r2: -1.06
# best of  53 => loss:     1975.62, corr:  0.21, r2: -4.63
# best of  54 => loss:     3774.04, corr: -0.01, r2: -10.74
# best of  55 => loss:     3172.59, corr:  0.29, r2: -0.73

# %% [markdown]
# # significance test

# %%
# data

df_to_run = pd.read_csv('data/deep_test_retest_imputed.csv')
# df_to_run = pd.read_csv('data/deep_test_retest_imputed_measures_standardized.csv')
data_arr = df_to_run.iloc[:,2:].to_numpy()
X = data_arr[:, :12]
y_total = data_arr[:, 12:]

# %%
n_samples = 500
all_str = str()
for idx in range(56):
    y = y_total[:, idx]

    tensorboard_path = os.path.join('tensorboard5/', str(idx) + '_' + str(int(round(time.time() % 1, 5) * 1e5)))
    _, best_r = run_deep(X, y, idx, 0.2, 
                         train_batch_size=10, val_batch_size=5, 
                         learning_rate=1e-3, 
                         tensorboard_path=tensorboard_path, 
                         print_iteration=1, 
                         n_epochs=100,
                         tensorboard=False,
                         do_print=False)
    
    all_r = dict(loss = list(), corr = list(), r2 = list())
    for i in tqdm(range(n_samples)):
        np.random.shuffle(y)
        tensorboard_path = os.path.join('tensorboard5/', str(idx) + '_' + str(int(round(time.time() % 1, 5) * 1e5)))
        _, shuf_r = run_deep(X, y, idx, 0.2, 
                             train_batch_size=10, val_batch_size=5, 
                             learning_rate=1e-3, 
                             tensorboard_path=tensorboard_path, 
                             print_iteration=1, 
                             n_epochs=100,
                             tensorboard=False,
                             do_print=False)
        all_r['loss'].append(shuf_r['loss'])
        all_r['corr'].append(shuf_r['corr'])
        all_r['r2'].append(shuf_r['r2'])
    
    p_loss = 0
    p_corr = 0
    p_r2 = 0
    for i in range(n_samples):
        p_loss += 1 if all_r['loss'][i] < best_r['loss'] else 0
        p_corr += 1 if all_r['corr'][i] > best_r['corr'] else 0
        p_r2 += 1 if all_r['r2'][i] > best_r['r2'] else 0
        
    print(f'idx {idx} \np_value of loss: {p_loss} \np_value of corr: {p_corr} \np_value of r2: {p_r2}')
    print('\n================\n')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 0
# p_value of loss: 32
# p_value of corr: 2
# p_value of r2: 1
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:46<00:00,  1.44it/s]
# idx 1
# p_value of loss: 355
# p_value of corr: 37
# p_value of r2: 20
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [06:11<00:00,  1.35it/s]
# idx 2
# p_value of loss: 309
# p_value of corr: 3
# p_value of r2: 5
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [06:47<00:00,  1.23it/s]
# idx 3
# p_value of loss: 210
# p_value of corr: 129
# p_value of r2: 126
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 4
# p_value of loss: 93
# p_value of corr: 51
# p_value of r2: 56
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.53it/s]
# idx 5
# p_value of loss: 241
# p_value of corr: 21
# p_value of r2: 329
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.53it/s]
# idx 6
# p_value of loss: 340
# p_value of corr: 53
# p_value of r2: 23
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.52it/s]
# idx 7
# p_value of loss: 203
# p_value of corr: 270
# p_value of r2: 394
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.52it/s]
# idx 8
# p_value of loss: 181
# p_value of corr: 318
# p_value of r2: 402
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.53it/s]
# idx 9
# p_value of loss: 318
# p_value of corr: 2
# p_value of r2: 2
#
# ================
#  58%|███████████████████████████████████████████████▏                                 | 291/500 [03:10<02:17,  1.52it/s]/Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ...
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/matin/miniconda3/envs/phd_codes/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 11
# p_value of loss: 476
# p_value of corr: 175
# p_value of r2: 120
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 12
# p_value of loss: 381
# p_value of corr: 373
# p_value of r2: 236
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 13
# p_value of loss: 30
# p_value of corr: 11
# p_value of r2: 5
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:30<00:00,  1.51it/s]
# idx 14
# p_value of loss: 48
# p_value of corr: 0
# p_value of r2: 0
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 15
# p_value of loss: 494
# p_value of corr: 314
# p_value of r2: 483
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 16
# p_value of loss: 176
# p_value of corr: 40
# p_value of r2: 4
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 17
# p_value of loss: 427
# p_value of corr: 366
# p_value of r2: 329
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 18
# p_value of loss: 68
# p_value of corr: 52
# p_value of r2: 232
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 19
# p_value of loss: 318
# p_value of corr: 49
# p_value of r2: 26
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 20
# p_value of loss: 272
# p_value of corr: 274
# p_value of r2: 197
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:29<00:00,  1.52it/s]
# idx 21
# p_value of loss: 303
# p_value of corr: 435
# p_value of r2: 427
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 22
# p_value of loss: 20
# p_value of corr: 98
# p_value of r2: 456
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 23
# p_value of loss: 33
# p_value of corr: 65
# p_value of r2: 133
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 24
# p_value of loss: 49
# p_value of corr: 0
# p_value of r2: 1
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.52it/s]
# idx 25
# p_value of loss: 207
# p_value of corr: 85
# p_value of r2: 46
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 26
# p_value of loss: 247
# p_value of corr: 283
# p_value of r2: 153
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 27
# p_value of loss: 27
# p_value of corr: 191
# p_value of r2: 55
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 28
# p_value of loss: 132
# p_value of corr: 34
# p_value of r2: 23
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 29
# p_value of loss: 61
# p_value of corr: 309
# p_value of r2: 355
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 30
# p_value of loss: 62
# p_value of corr: 27
# p_value of r2: 17
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 31
# p_value of loss: 388
# p_value of corr: 81
# p_value of r2: 390
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 32
# p_value of loss: 229
# p_value of corr: 22
# p_value of r2: 36
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 33
# p_value of loss: 114
# p_value of corr: 168
# p_value of r2: 115
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 34
# p_value of loss: 169
# p_value of corr: 4
# p_value of r2: 3
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 35
# p_value of loss: 477
# p_value of corr: 178
# p_value of r2: 106
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 36
# p_value of loss: 382
# p_value of corr: 117
# p_value of r2: 44
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 37
# p_value of loss: 352
# p_value of corr: 132
# p_value of r2: 40
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 38
# p_value of loss: 101
# p_value of corr: 265
# p_value of r2: 243
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 39
# p_value of loss: 153
# p_value of corr: 233
# p_value of r2: 229
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 40
# p_value of loss: 5
# p_value of corr: 17
# p_value of r2: 6
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 41
# p_value of loss: 190
# p_value of corr: 40
# p_value of r2: 16
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.52it/s]
# idx 42
# p_value of loss: 0
# p_value of corr: 12
# p_value of r2: 5
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:27<00:00,  1.52it/s]
# idx 43
# p_value of loss: 409
# p_value of corr: 157
# p_value of r2: 94
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 44
# p_value of loss: 209
# p_value of corr: 167
# p_value of r2: 120
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 45
# p_value of loss: 39
# p_value of corr: 22
# p_value of r2: 5
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 46
# p_value of loss: 221
# p_value of corr: 32
# p_value of r2: 32
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 47
# p_value of loss: 293
# p_value of corr: 56
# p_value of r2: 204
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 48
# p_value of loss: 24
# p_value of corr: 0
# p_value of r2: 0
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 49
# p_value of loss: 34
# p_value of corr: 9
# p_value of r2: 7
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 50
# p_value of loss: 223
# p_value of corr: 138
# p_value of r2: 322
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 51
# p_value of loss: 50
# p_value of corr: 404
# p_value of r2: 215
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 52
# p_value of loss: 29
# p_value of corr: 299
# p_value of r2: 61
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 53
# p_value of loss: 20
# p_value of corr: 0
# p_value of r2: 20
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 54
# p_value of loss: 59
# p_value of corr: 241
# p_value of r2: 121
#
# ================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 500/500 [05:28<00:00,  1.52it/s]
# idx 55
# p_value of loss: 326
# p_value of corr: 100
# p_value of r2: 295
#
# ================
