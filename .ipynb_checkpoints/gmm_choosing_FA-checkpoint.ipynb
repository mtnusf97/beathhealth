# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, normalize
import scipy.cluster.hierarchy as shc
from sklearn.manifold import TSNE
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %matplotlib inline

# %% [markdown]
# # define data

# %% [markdown]
# ### normalized data

# %%
df_normalized = pd.read_csv('data/baasta-data-joncannon_outlier_rejected_normalized.csv')

# %%
df_normalized['Paced_music_mean_CV_iti'] = np.mean(df_normalized[['Paced_music_badine_mean_CV_iti', 'Paced_music_ross_mean_CV_iti']])

# %%
fiveash_columns = [
    'BAT_all_dprime',
    'Anisochrony_tones_threshold',
    'Unpaced_spontaneous_right_CV_iti',
    'SyncCont_metro_600_mean_CV_iti',
    'Paced_metro_600_mean_CV_iti',
]
#     'Paced_music_mean_CV_iti',


df_normalized_fivash = df_normalized[fiveash_columns]

# %% [markdown]
# ### tSNE data

# %%
tsne_norm = TSNE(n_components=2, learning_rate='auto',init='random', perplexity=10)
tsne_normalized_data = tsne_norm.fit_transform(df_normalized.iloc[:,2:])
sns.scatterplot(x=tsne_normalized_data[:,0], y=tsne_normalized_data[:,1])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### PCA data

# %%
pca_norm = PCA(n_components=2)
pca_norm.fit(df_normalized.iloc[:,2:])
pca_normalized_data = pca_norm.transform(X=df_normalized.iloc[:,2:])
sns.scatterplot(x=pca_normalized_data[:,0], y=pca_normalized_data[:,1])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### synthetic data

# %%
n_samples = 500
np.random.seed(0)
C = np.array([[0.0, -0.1], [1.7, 0.4]])
component_1 = np.dot(np.random.randn(n_samples, 2), C)  # general
component_2 = 0.7 * np.random.randn(n_samples, 2) + np.array([-4, 1])  # spherical
synthetic_X = np.concatenate([component_1, component_2])

# %% [markdown]
# ### define X

# %%
# X = tsne_normalized_data
# X = pca_normalized_data
X = df_normalized.iloc[:,2:]
# X = synthetic_X

# %% [markdown]
# # BIC method

# %% [markdown]
# ## define score

# %%
def gmm_bic_score(estimator, X):
    return -estimator.bic(X)

# %% [markdown]
# ## define grid search

# %%
param_grid = {
    "n_components": range(1, 7),
    "covariance_type": ["spherical", "tied", "diag", "full"],
}
grid_search = GridSearchCV(
    GaussianMixture(), param_grid=param_grid, scoring=gmm_bic_score
)

# %% [markdown]
# ## fit grid search

# %%
grid_search.fit(X)
# Out:
# GridSearchCV(estimator=GaussianMixture(),
#              param_grid={'covariance_type': ['spherical', 'tied', 'diag',
#                                              'full'],
#                          'n_components': range(1, 7)},
#              scoring=<function gmm_bic_score at 0x7f5be08ca440>)

# %% [markdown]
# ## show dataframe of results

# %%
df = pd.DataFrame(grid_search.cv_results_)[
    ["param_n_components", "param_covariance_type", "mean_test_score"]
]
df["mean_test_score"] = -df["mean_test_score"]
df = df.rename(
    columns={
        "param_n_components": "Number of components",
        "param_covariance_type": "Type of covariance",
        "mean_test_score": "BIC score",
    }
)
df.sort_values(by="BIC score").head()
# Out:
#    Number of components Type of covariance     BIC score
# 12                    1               diag -10962.730732
# 13                    2               diag -10693.191761
# 14                    3               diag -10394.249039
# 15                    4               diag -10043.336723
# 16                    5               diag  -9692.064717

# %% [markdown]
# ## plot the results

# %%
sns.catplot(
    data=df,
    kind="bar",
    x="Number of components",
    y="BIC score",
    hue="Type of covariance",
)
plt.show()

# %%
bics_err = -df[df['Type of covariance'] == 'spherical']['BIC score']
n_clusters = np.arange(1,7)
plt.plot(n_clusters,bics_err, label='BIC')
plt.title("BIC Scores", fontsize=20)
plt.xticks(n_clusters)
plt.xlabel("N. of clusters")
plt.ylabel("Score")
plt.legend()

# %% [markdown]
# # Silohuette coefficient

# %% [markdown]
# ## define score

# %%
def gmm_silohuette_score(estimator, X):
    labels=estimator.predict(X)
#     print('here labels:', len(labels), '\n', labels)
    sil=metrics.silhouette_score(X, labels, metric='euclidean')
    return sil

# %% [markdown]
# ## define grid search

# %%
param_grid = {
    "n_components": range(2, 7),
    "covariance_type": ["spherical", "tied", "diag", "full"],
}
grid_search = GridSearchCV(
    GaussianMixture(), param_grid=param_grid, scoring=gmm_silohuette_score
)

# %% [markdown]
# ## fit grid search

# %%
grid_search.fit(X)
# Out:
# GridSearchCV(estimator=GaussianMixture(),
#              param_grid={'covariance_type': ['spherical', 'tied', 'diag',
#                                              'full'],
#                          'n_components': range(2, 7)},
#              scoring=<function gmm_silohuette_score at 0x7fd7da400ee0>)

# %% [markdown]
# ## show dataframe of results

# %%
df = pd.DataFrame(grid_search.cv_results_)[
    ["param_n_components", "param_covariance_type", "mean_test_score"]
]
df = df.rename(
    columns={
        "param_n_components": "Number of components",
        "param_covariance_type": "Type of covariance",
        "mean_test_score": "Silohuette score",
    }
)
df.sort_values(by="Silohuette score").tail()
# Out:
#    Number of components Type of covariance  Silohuette score
# 1                     3          spherical          0.198281
# 15                    2               full          0.315513
# 10                    2               diag          0.335274
# 5                     2               tied          0.399348
# 0                     2          spherical          0.424408

# %% [markdown]
# ## plot the results

# %%
sns.catplot(
    data=df,
    kind="bar",
    x="Number of components",
    y="Silohuette score",
    hue="Type of covariance",
)
plt.show()

# %% [markdown]
# # PCA results BIC Original

# %%
pca_n_components = range(2, 60)
gmm_n_components = range(1, 7)
gmm_covariance = ["spherical", "tied", "diag", "full"]
results = {'pca_n_components':[], 'gmm_n_components':[], 'gmm_covariance':[], 'test_score':[]}
X = df_normalized.iloc[:,2:]
for pca_n in pca_n_components:
    for gmm_n in gmm_n_components:
        for c_type in gmm_covariance:
            pca = PCA(n_components=pca_n)
            pca.fit(X)
            x_pca = pca.transform(X)
            gmm=GaussianMixture(n_components=gmm_n, covariance_type=c_type).fit(x_pca) 
            test_score = gmm.bic(x_pca)
            results['pca_n_components'].append(pca_n)
            results['gmm_n_components'].append(gmm_n)
            results['gmm_covariance'].append(c_type)
            results['test_score'].append(test_score)

            
df_result = pd.DataFrame(results)[["pca_n_components", "gmm_n_components", "gmm_covariance", "test_score"]]

# %%
df_result.sort_values(by='test_score')
# Out:
#       pca_n_components  gmm_n_components gmm_covariance    test_score
# 1370                59                 1           diag -61064.764392
# 1374                59                 2           diag -60758.298431
# 1378                59                 3           diag -60269.237215
# 1382                59                 4           diag -59824.106799
# 1346                58                 1           diag -59780.544237
# ...                ...               ...            ...           ...
# 15                   2                 4           full   -274.305232
# 18                   2                 5           diag   -270.477193
# 19                   2                 5           full   -257.313042
# 22                   2                 6           diag   -253.999947
# 23                   2                 6           full   -229.393813
#
# [1392 rows x 4 columns]

# %%
gmm_two_works = []

for pca_n in pca_n_components:
    for c_type in gmm_covariance:
        temp_df = df_result[(df_result['gmm_covariance']==c_type) & (df_result['pca_n_components']==pca_n)]
        if temp_df.sort_values(by='test_score')['gmm_n_components'].values[0] == 1:
            value = temp_df[temp_df['gmm_n_components']==1]['test_score']
            gmm_two_works.append(f'{str(pca_n)} with {str(c_type)} works with value {value.values[0]}' )

gmm_two_works
# Out:
# ['4 with full works with value -933.9383101639544',
#  '5 with full works with value -1428.0807276599303',
#  '6 with diag works with value -2015.3243941854314',
#  '6 with full works with value -1945.092425778568',
#  '8 with diag works with value -3205.420735963401',
#  '9 with diag works with value -3832.8181558559218',
#  '10 with diag works with value -4492.511596731005',
#  '10 with full works with value -4281.815691510417',
#  '11 with diag works with value -5174.884189039835',
#  '11 with full works with value -4917.366971548003',
#  '12 with diag works with value -5895.627255181319',
#  '12 with full works with value -5586.606594191121',
#  '13 with diag works with value -6642.231488611462',
#  '13 with full works with value -6277.0252528957735',
#  '14 with diag works with value -7416.507004462525',
#  '14 with full works with value -6990.433062794221',
#  '15 with diag works with value -8204.515263029094',
#  '15 with full works with value -7712.891484181051',
#  '16 with diag works with value -9004.20278952348',
#  '16 with full works with value -8442.347042268573',
#  '17 with diag works with value -9843.002452276161',
#  '17 with full works with value -9206.232605387268',
#  '18 with diag works with value -10703.156807135221',
#  '18 with full works with value -9986.790729385213',
#  '19 with tied works with value -10784.860806357901',
#  '19 with diag works with value -11585.505246196142',
#  '19 with full works with value -10784.860806357901',
#  '20 with tied works with value -11617.609356564692',
#  '20 with full works with value -11617.609356564692',
#  '21 with tied works with value -12486.230820558385',
#  '21 with diag works with value -13469.478378254473',
#  '21 with full works with value -12486.230820558385',
#  '22 with tied works with value -13404.91698915619',
#  '22 with diag works with value -14486.489302621885',
#  '22 with full works with value -13404.91698915619',
#  '23 with tied works with value -14346.886333811519',
#  '23 with full works with value -14346.886333811519',
#  '24 with tied works with value -15329.781736305022',
#  '24 with full works with value -15329.781736305018',
#  '25 with tied works with value -16390.63497479644',
#  '25 with diag works with value -17795.27434293371',
#  '25 with full works with value -16390.634974796434',
#  '26 with tied works with value -17471.958604456304',
#  '26 with diag works with value -18993.651253271677',
#  '26 with full works with value -17471.9586044563',
#  '27 with tied works with value -18573.755060095005',
#  '27 with diag works with value -20217.183120815604',
#  '27 with full works with value -18573.755060095005',
#  '28 with tied works with value -19677.562251138217',
#  '28 with diag works with value -21447.407854991172',
#  '28 with full works with value -19677.562251138217',
#  '29 with tied works with value -20788.777272049887',
#  '29 with diag works with value -22689.72255026232',
#  '29 with full works with value -20788.777272049887',
#  '30 with tied works with value -21900.460353362894',
#  '30 with diag works with value -23937.18743716193',
#  '30 with full works with value -21900.460353362894',
#  '31 with tied works with value -23018.655450798764',
#  '31 with diag works with value -25195.846471411525',
#  '31 with full works with value -23018.655450798764',
#  '32 with tied works with value -24141.195338561192',
#  '32 with diag works with value -26463.532427214806',
#  '32 with full works with value -24141.195338561203',
#  '33 with tied works with value -25260.450982080147',
#  '33 with diag works with value -27732.616270001734',
#  '33 with full works with value -25260.450982080147',
#  '34 with tied works with value -26377.66891849333',
#  '34 with diag works with value -29004.34453691002',
#  '34 with full works with value -26377.66891849333',
#  '35 with tied works with value -27491.9979962103',
#  '35 with diag works with value -30277.86607634921',
#  '35 with full works with value -27491.997996210303',
#  '36 with tied works with value -28602.831744697887',
#  '36 with diag works with value -31552.57441778615',
#  '36 with full works with value -28602.8317446979',
#  '37 with tied works with value -29710.958691811644',
#  '37 with diag works with value -32829.25808907637',
#  '37 with full works with value -29710.958691811644',
#  '38 with tied works with value -30815.242619826713',
#  '38 with diag works with value -34106.78087249504',
#  '38 with full works with value -30815.24261982672',
#  '39 with tied works with value -31916.19682215619',
#  '39 with diag works with value -35385.656061455236',
#  '39 with full works with value -31916.19682215619',
#  '40 with tied works with value -33015.15534738682',
#  '40 with diag works with value -36667.217704543706',
#  '40 with full works with value -33015.15534738682',
#  '41 with tied works with value -34111.139357832144',
#  '41 with diag works with value -37950.48696407401',
#  '41 with full works with value -34111.139357832144',
#  '42 with tied works with value -35202.634982110234',
#  '42 with diag works with value -39233.949968664194',
#  '42 with full works with value -35202.634982110234',
#  '43 with tied works with value -36289.604050496564',
#  '43 with diag works with value -40517.568548589734',
#  '43 with full works with value -36289.604050496564',
#  '44 with tied works with value -37372.28389690228',
#  '44 with diag works with value -41801.58003776179',
#  '44 with full works with value -37372.28389690228',
#  '45 with tied works with value -38450.449807347955',
#  '45 with diag works with value -43085.75972220094',
#  '45 with full works with value -38450.449807347955',
#  '46 with tied works with value -39523.95025230067',
#  '46 with diag works with value -44369.95607237423',
#  '46 with full works with value -39523.95025230067',
#  '47 with tied works with value -40592.77323284665',
#  '47 with diag works with value -45654.15708936794',
#  '47 with full works with value -40592.77323284665',
#  '48 with tied works with value -41656.92206043767',
#  '48 with diag works with value -46938.36608463379',
#  '48 with full works with value -41656.92206043767',
#  '49 with tied works with value -42716.39460403928',
#  '49 with diag works with value -48222.58092713736',
#  '49 with full works with value -42716.39460403928',
#  '50 with tied works with value -43771.185776585524',
#  '50 with diag works with value -49506.796529812695',
#  '50 with full works with value -43771.185776585524',
#  '51 with tied works with value -44821.294896525476',
#  '51 with diag works with value -50791.01221110886',
#  '51 with full works with value -44821.294896525476',
#  '52 with tied works with value -45866.72396470024',
#  '52 with diag works with value -52075.22997186696',
#  '52 with full works with value -45866.72396470024',
#  '53 with tied works with value -46907.47148036015',
#  '53 with diag works with value -53359.44831133733',
#  '53 with full works with value -46907.47148036015',
#  '54 with tied works with value -47943.53709992841',
#  '54 with diag works with value -54643.666885943174',
#  '54 with full works with value -47943.53709992841',
#  '55 with tied works with value -48974.920774824364',
#  '55 with diag works with value -55927.88564710383',
#  '55 with full works with value -48974.920774824364',
#  '56 with tied works with value -50001.622601465686',
#  '56 with diag works with value -57212.104691236986',
#  '56 with full works with value -50001.622601465686',
#  '57 with tied works with value -51023.64264386148',
#  '57 with diag works with value -58496.32408235173',
#  '57 with full works with value -51023.64264386148',
#  '58 with tied works with value -52040.981318549086',
#  '58 with diag works with value -59780.54423698542',
#  '58 with full works with value -52040.981318549086',
#  '59 with tied works with value -53053.63786200955',
#  '59 with diag works with value -61064.76439161909',
#  '59 with full works with value -53053.63786200955']

# %%
df_result[(df_result['gmm_covariance']=='spherical') & (df_result['pca_n_components']==59)].sort_values(by='test_score')
# Out:
#       pca_n_components  gmm_n_components gmm_covariance    test_score
# 1388                59                 6      spherical -34279.819287
# 1384                59                 5      spherical -34172.458371
# 1380                59                 4      spherical -33832.276453
# 1376                59                 3      spherical -32981.447373
# 1372                59                 2      spherical -32087.205831
# 1368                59                 1      spherical -28632.842451

# %% [markdown]
# # PCA results BIC Fivash

# %%
df_normalized_fivash.shape
# Out:
# (108, 5)

# %%
pca_n_components = range(2, 4)
gmm_n_components = range(1, 7)
gmm_covariance = ["spherical", "tied", "diag", "full"]
results = {'pca_n_components':[], 'gmm_n_components':[], 'gmm_covariance':[], 'test_score':[]}
X = df_normalized_fivash.iloc[:,2:]
for pca_n in pca_n_components:
    for gmm_n in gmm_n_components:
        for c_type in gmm_covariance:
            pca = PCA(n_components=pca_n)
            pca.fit(X)
            x_pca = pca.transform(X)
            gmm=GaussianMixture(n_components=gmm_n, covariance_type=c_type).fit(x_pca) 
            test_score = gmm.bic(x_pca)
            results['pca_n_components'].append(pca_n)
            results['gmm_n_components'].append(gmm_n)
            results['gmm_covariance'].append(c_type)
            results['test_score'].append(test_score)

            
df_result = pd.DataFrame(results)[["pca_n_components", "gmm_n_components", "gmm_covariance", "test_score"]]

# %%
df_result
# Out:
#     pca_n_components  gmm_n_components gmm_covariance   test_score
# 0                  2                 1      spherical -2573.073104
# 1                  2                 1           tied -2563.708844
# 2                  2                 1           diag -2568.390975
# 3                  2                 1           full -2563.708844
# 4                  2                 2      spherical -2554.344579
# 5                  2                 2           tied -2549.662450
# 6                  2                 2           diag -2544.980319
# 7                  2                 2           full -2535.616056
# 8                  2                 3      spherical -2535.616054
# 9                  2                 3           tied -2535.616056
# 10                 2                 3           diag -2521.569662
# 11                 2                 3           full -2507.523269
# 12                 2                 4      spherical -2516.887530
# 13                 2                 4           tied -2521.569662
# 14                 2                 4           diag -2498.159006
# 15                 2                 4           full -2479.430481
# 16                 2                 5      spherical -2498.159005
# 17                 2                 5           tied -2507.523269
# 18                 2                 5           diag -2474.748350
# 19                 2                 5           full -2451.337694
# 20                 2                 6      spherical -2479.430480
# 21                 2                 6           tied -2493.476875
# 22                 2                 6           diag -2451.337694
# 23                 2                 6           full -2423.244907
# 24                 3                 1      spherical -3861.972847
# 25                 3                 1           tied -3838.562194
# 26                 3                 1           diag -3852.608588
# 27                 3                 1           full -3838.562194
# 28                 3                 2      spherical -3838.562191
# 29                 3                 2           tied -3819.833669
# 30                 3                 2           diag -3819.833669
# 31                 3                 2           full -3791.740882
# 32                 3                 3      spherical -3815.151535
# 33                 3                 3           tied -3801.105144
# 34                 3                 3           diag -3787.058751
# 35                 3                 3           full -3744.919570
# 36                 3                 4      spherical -3791.740879
# 37                 3                 4           tied -3782.376619
# 38                 3                 4           diag -3754.283832
# 39                 3                 4           full -3698.098257
# 40                 3                 5      spherical -3768.330223
# 41                 3                 5           tied -3763.648094
# 42                 3                 5           diag -3721.508913
# 43                 3                 5           full -3651.276945
# 44                 3                 6      spherical -3744.919567
# 45                 3                 6           tied -3744.919570
# 46                 3                 6           diag -3688.733995
# 47                 3                 6           full -3604.455633

# %%
gmm_two_works = []

for pca_n in pca_n_components:
    for c_type in gmm_covariance:
        temp_df = df_result[(df_result['gmm_covariance']==c_type) & (df_result['pca_n_components']==pca_n)]
        if temp_df.sort_values(by='test_score')['gmm_n_components'].values[0] == 1:
            value = temp_df[temp_df['gmm_n_components']==1]['test_score']
            gmm_two_works.append(f'{str(pca_n)} with {str(c_type)} works with value {value.values[0]}' )

gmm_two_works
# Out:
# ['2 with spherical works with value -2573.0731042863767',
#  '2 with tied works with value -2563.7088435379255',
#  '2 with diag works with value -2568.3909747650496',
#  '2 with full works with value -2563.7088435379255',
#  '3 with spherical works with value -3861.9728474151607',
#  '3 with tied works with value -3838.562194118636',
#  '3 with diag works with value -3852.6085878000085',
#  '3 with full works with value -3838.562194118636']

# %%
df_result[(df_result['gmm_covariance']=='spherical') & (df_result['pca_n_components']==59)].sort_values(by='test_score')
# Out:
#       pca_n_components  gmm_n_components gmm_covariance    test_score
# 1388                59                 6      spherical -34279.819287
# 1384                59                 5      spherical -34172.458371
# 1380                59                 4      spherical -33832.276453
# 1376                59                 3      spherical -32981.447373
# 1372                59                 2      spherical -32087.205831
# 1368                59                 1      spherical -28632.842451
